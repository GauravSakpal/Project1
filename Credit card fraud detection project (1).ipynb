# %%
import pandas as pd
import numpy as np

# %%
#read DATASET
data=pd.read_csv(r"C:\Users\gaura\Downloads\creditcard.csv\creditcard.csv")

# %%
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
data.tail()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# ...

# %%
#Findout is there any null values in dataset
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
#findout dataset is balance or imbalanced
data.Class.value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
#Separation of data based on target function
legit=data[data.Class==0]
fraud=data[data.Class==1]

# %%
legit
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
fraud
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 541        406.0 -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545
# 623        472.0 -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823
# 4920      4462.0 -2.303350  1.759247 -0.359745  2.330243 -0.821628 -0.075788
# 6108      6986.0 -4.397974  1.358367 -2.592844  2.679787 -1.128131 -1.706536
# 6329      7519.0  1.234235  3.019740 -4.304597  4.732795  3.624201 -1.357746
# ...          ...       ...       ...       ...       ...       ...       ...
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
# ...

# %%
print(legit.shape)
print(fraud.shape)
# Out:
# (284315, 31)
# (492, 31)

# %%
#Analysed data
legit.Amount.describe()
# Out:
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
data.groupby("Class").mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      94838.202258  0.008258 -0.006271  0.012171 -0.007860  0.005453
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.002419  0.009637 -0.000987  0.004467  ... -0.000644 -0.001235
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.000024  0.000070  0.000182 -0.000072 -0.000089 -0.000295 -0.000131
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       88.291022
# 1      122.211321
#
# [2 rows x 30 columns]

# %%
#undersampling for balance data
legit_data=legit.sample(n=492)

# %%
legit_data
# Out:
#             Time         V1        V2        V3        V4        V5        V6  \
# 60607    49401.0  -0.260088  0.087663  1.789451  0.067966 -0.735352  0.127730
# 158917  111962.0  -0.239924  1.256615  1.815907  3.205555  0.494817  1.053218
# 48371    43614.0   1.283485 -0.814912  1.068031 -0.673167 -1.647223 -0.542837
# 170954  120425.0   1.968730 -0.184647 -1.289465  0.364810  0.191130 -0.479241
# 268814  163391.0   2.126666 -0.889500 -1.442241 -1.051407 -0.431247 -0.758406
# ...          ...        ...       ...       ...       ...       ...       ...
# 49864    44245.0   1.072468 -0.108920  0.736977  1.396975 -0.573758  0.189087
# 73087    54969.0  -0.351484  0.627748  2.204289  0.671704 -0.268058  0.113172
# 954        722.0  -1.133413 -0.018861  1.343241  2.017042 -3.020240  2.609574
# 76175    56431.0  -0.731126  0.289664  1.942438 -1.875865 -0.509112 -0.581825
# 22092    32031.0 -10.201717 -6.026449  0.124710  0.534225  0.570225 -0.123100
#
# ...

# %%
#Concadinate two balance dataset
new_data=pd.concat([legit_data,fraud])

# %%
new_data
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 60607    49401.0 -0.260088  0.087663  1.789451  0.067966 -0.735352  0.127730
# 158917  111962.0 -0.239924  1.256615  1.815907  3.205555  0.494817  1.053218
# 48371    43614.0  1.283485 -0.814912  1.068031 -0.673167 -1.647223 -0.542837
# 170954  120425.0  1.968730 -0.184647 -1.289465  0.364810  0.191130 -0.479241
# 268814  163391.0  2.126666 -0.889500 -1.442241 -1.051407 -0.431247 -0.758406
# ...          ...       ...       ...       ...       ...       ...       ...
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
# ...

# %%
new_data.Class.value_counts()
# Out:
# 0    492
# 1    492
# Name: Class, dtype: int64

# %%
new_data.groupby("Class").mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      94650.213415 -0.004258  0.055624  0.060087 -0.058702  0.047770
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.050409 -0.052369 -0.060814 -0.000320  ...  0.005295  0.022391
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0      0.050540  0.000991  0.048297 -0.023015  0.030060 -0.015284  0.017574
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       75.804472
# 1      122.211321
#
# [2 rows x 30 columns]

# %%
#Splitting the data into Features & Targets
X=new_data.drop(columns="Class",axis=1)
Y=new_data["Class"]

# %%
X
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 60607    49401.0 -0.260088  0.087663  1.789451  0.067966 -0.735352  0.127730
# 158917  111962.0 -0.239924  1.256615  1.815907  3.205555  0.494817  1.053218
# 48371    43614.0  1.283485 -0.814912  1.068031 -0.673167 -1.647223 -0.542837
# 170954  120425.0  1.968730 -0.184647 -1.289465  0.364810  0.191130 -0.479241
# 268814  163391.0  2.126666 -0.889500 -1.442241 -1.051407 -0.431247 -0.758406
# ...          ...       ...       ...       ...       ...       ...       ...
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
# ...

# %%
Y
# Out:
# 60607     0
# 158917    0
# 48371     0
# 170954    0
# 268814    0
#          ..
# 279863    1
# 280143    1
# 280149    1
# 281144    1
# 281674    1
# Name: Class, Length: 984, dtype: int64

# %%
#Split the data into Training data & Testing Data

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size=0.2,stratify=Y,random_state=2)

# %%
print(X.shape,X_train.shape,X_test.shape)
# Out:
# (984, 30) (787, 30) (197, 30)

# %%
#Model Training

#Logistic Regression

model=LogisticRegression()
model.fit(X_train, Y_train)
# Out:
# LogisticRegression()

# %%
#Model Evaluation

#Accuracy Score

# accuracy on training data
X_train_pred=model.predict(X_train)
train_data_accuracy=accuracy_score(Y_train, X_train_pred )
print(train_data_accuracy)
# Out:
# 0.9542566709021602

# %%
# accuracy on test data
X_test_pred=model.predict(X_test)
test_data_accuracy=accuracy_score(Y_test, X_test_pred)
print(test_data_accuracy)
# Out:
# 0.9441624365482234

# %%
#Confusion metrix
from sklearn.metrics import confusion_matrix

# %%
cf_matrix_test=confusion_matrix( Y_test, X_test_pred)
print(cf_matrix_test)
# Out:
# [[97  2]
#  [ 9 89]]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.heatmap(cf_matrix_test, annot=True)
plt.xlabel("Predicated values")
plt.ylabel("True values")
plt.title("Confussion matrix")
# Out:
# Text(0.5, 1.0, 'Confussion matrix')

# %%
#Precision
from sklearn.metrics import precision_score

precision_score_test=precision_score(Y_test, X_test_pred)
print(precision_score_test)
# Out:
# 0.978021978021978

# %%
#Recall
from sklearn.metrics import recall_score

recall_score_test=recall_score(Y_test, X_test_pred)
print(recall_score_test)
# Out:
# 0.9081632653061225

# %%
#F1 Score
from sklearn.metrics import f1_score

f1_score_test=f1_score(Y_test, X_test_pred)
print(f1_score_test)
# Out:
# 0.9417989417989417

# %%
def precision_recall_f1_score(true_labels, pred_labels):
    precision_value = precision_score(true_labels, pred_labels)
    recall_value = recall_score(true_labels, pred_labels)
    f1_score_value = f1_score(true_labels, pred_labels)

    print('Precision =',precision_value)
    print('Recall =',recall_value)
    print('F1 Score =',f1_score_value)

# %%
# classification metrics for test data
precision_recall_f1_score(Y_test , X_test_pred)
# Out:
# Precision = 0.978021978021978
# Recall = 0.9081632653061225
# F1 Score = 0.9417989417989417

# %%
# classification metrics for train data
precision_recall_f1_score(Y_train , X_train_pred)
# Out:
# Precision = 0.9811827956989247
# Recall = 0.9263959390862944
# F1 Score = 0.9530026109660574

# %%
from sklearn.model_selection import cross_val_score

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=4)
print(cross_val_score(knn, X, Y, cv=10, scoring ='accuracy').mean())
# Out:
# 0.45844155844155854

# %%
from sklearn.linear_model import LogisticRegression
logireg = LogisticRegression()
print(cross_val_score(logireg, X, Y, cv=10, scoring ='accuracy').mean())
# Out:
# C:\Users\gaura\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\gaura\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
import seaborn as sns

# %%
sns.pairplot(new_data, hue='Class')
